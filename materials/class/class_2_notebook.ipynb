# %% [markdown]
# **Instructions:**
# 1. This version of the activities cannot be edited. To save an editable version, copy this Colab file to your individual class Google Drive folder ("OCEAN 215 - Autumn '20 - {your name}") by right clicking on this file and selecting "Move to".
# 2. Open the version you copied.
# 3. Complete the activities

# %% [markdown]
# # **Debugging activity**

# %%
# Activity 1: debugging
# -----------------------------------------------------------------------------

# Here are the Beatles' names
# 1st_beatle = 'John'
# 2nd_beatle = 'Paul
# 3rd_beatle = 'George"
# 4th_beatle = 'Ringo'

# # Here are the Beatles' ages
# age1 = '23'
# age2 = '21'
# age3 = '20'
# age4 = '23'

# # This is the age range of the Beatles
# age range = age1 - age3

# # Here are a few print statements
# print('The Beatles were', age1 age2 age3 'and' age4, 'when they arrived in America.')
# print('Their names were:',1st_beatle+2nd_beatle+3rd_beatle+'and'+4th_beatle.)
# print('The youngest Beatle's name was,' 3rd_beatle')

# Here are the Beatles' names
beatle1 = 'John'
beatle2 = 'Paul'
beatle3 = 'George'
beatle4 = 'Ringo'

# Here are the Beatles' ages
age1 = 23
age2 = 21
age3 = 20
age4 = 23

# This is the age range of the Beatles
age_range = age1 - age3

# Here are a few print statements
print('The Beatles were', age1, age2, age3, 'and', age4, 'when they arrived in America.')

# These two lines produce the same result, but in different ways. Both are correct!
print('Their names were:', beatle1 + ' ' + beatle2 + ' ' + beatle3 + ' and ' + beatle4 + '.')
print('Their names were:', beatle1, beatle2, beatle3, 'and', beatle4 + '.')

# These two lines produce the same result, but in different ways. Both are correct!
print("The youngest Beatle's name was", beatle3)
print('The youngest Beatle\'s name was', beatle3)
# Out:
# The Beatles were 23 21 20 and 23 when they arrived in America.
# Their names were: John Paul George and Ringo.
# Their names were: John Paul George and Ringo.
# The youngest Beatle's name was George
# The youngest Beatle's name was George

# %% [markdown]
# # **Alphabet slicing activity**

# %% [markdown]
# ![Screen Shot 2020-10-07 at 2.38.53 PM.png](data:image/png;base64,...)

# %%
# Activity 2: string indexing and slicing
# -----------------------------------------------------------------------------

abc_str = 'the quick brown fox jumped over the lazy dog'

# Select the letters in your name (First and Last) by slicing this string using the index values shown. 
let_1 = abc_str[8]         # k     (let stands for letter here)
let_2 = abc_str[37]        # a
let_3 = abc_str[0]         # t
let_4 = abc_str[39]        # y

let_5 = abc_str[7]          # c
let_6 = abc_str[1]          # h
let_7 = abc_str[11]         # r
let_8 = abc_str[6]          # i
let_9 = 's'                 # s    (oops - should have been in abc_str, but wasn't)
let_10 = abc_str[0]         # t
let_11 = abc_str[24]        # e
let_12 = abc_str[14]        # n
let_13 = 's'                # s    (same as above)
let_14 = abc_str[24]        # e
let_15 = abc_str[14]        # n

# Then create a single string out of the letters to write your full name
# Capitalize the first letter of you first and last names using the upper function!
# Separate your first and last names with a space

# All-lowercase version:
first_name_lowercase = let_1 + let_2 + let_3 + let_4
last_name_lowercase = let_5 + let_6 + let_7 + let_8 + let_9 + let_10 + let_11 + let_12 + let_13 + let_14 + let_15
full_name_lowercase = first_name_lowercase + ' ' + last_name_lowercase
print(full_name_lowercase)

# Properly capitalized version:
first_name_capitalized = let_1.upper() + let_2 + let_3 + let_4
last_name_capitalized = let_5.upper() + let_6 + let_7 + let_8 + let_9 + let_10 + let_11 + let_12 + let_13 + let_14 + let_15
full_name_capitalized = first_name_capitalized + ' ' + last_name_capitalized
print(full_name_capitalized)
# Note that another way to do this would be to add .upper() in the code above *instead* of here:
#      let_1 = abc_str[8].upper()
#      let_5 = abc_str[7].upper()

# Write a print statement with the result:
# My name is <Lastname>, <Firstname> <Lastname>.  (Example: My name is Bond, James Bond.)
print(last_name_capitalized + ', ' + first_name_capitalized + ' ' + last_name_capitalized)
# Out:
# katy christensen
# Katy Christensen
# Christensen, Katy Christensen
